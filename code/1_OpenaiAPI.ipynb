# %% [markdown]
# # OpenAI API - Chat completions API
# Chat models process a sequence of messages to generate a single output message, facilitating both multi-turn conversations and single-turn tasks efficiently.

# %%
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())
# Out:
# True

# %%
import openai

response = openai.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant specialized in providing turistic info about cities"},
        {"role": "user", "content": "Tell me one fun fact about Catania, Sicily"},
    ]
)

# %%
print(response)
# Out:
# ChatCompletion(id='chatcmpl-9SDls2JJNbJ2DBs9WtZcKGHjpjORv', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='One fun fact about Catania, Sicily is that it is home to Mount Etna, one of the most active volcanoes in the world. Visitors can take guided tours to explore the volcanic landscape and even see lava flows under certain conditions.', role='assistant', function_call=None, tool_calls=None))], created=1716513148, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=50, prompt_tokens=35, total_tokens=85))

# %%
print(response.choices[0].message.content)
# Out:
# One fun fact about Catania, Sicily is that it is home to Mount Etna, one of the most active volcanoes in the world. Visitors can take guided tours to explore the volcanic landscape and even see lava flows under certain conditions.

# %%
from openai import OpenAI

client = OpenAI()

embedding= client.embeddings.create(
    model="text-embedding-ada-002",
    input="Mark was playing tennis with his friends",
    encoding_format="float",
)

# %%
print(embedding)
# Out:
# CreateEmbeddingResponse(data=[Embedding(embedding=[-0.025143024, 0.0022538255, 0.0213123, -0.00019594246, 0.005321836, 0.03763343, -0.012072395, 0.0007658328, -0.018991405, -0.03376527, 0.012309475, 0.016346084, -0.013613419, 0.0048320773, 0.001366333, -0.018791758, 0.02557975, -0.019677691, 0.018454853, -0.026053913, -0.0063387873, 0.009464508, 0.001035668, -0.031194817, -0.022896996, 0.008353972, -0.0024425543, -0.0232339, 0.016782813, 0.0069564446, 0.035362445, -0.004835197, -0.014599175, 0.0087907, -0.019814948, -0.005502766, -0.0071248966, 0.0010083725, 0.015934313, -0.013089346, 0.005795997, 0.0022850204, -0.00632007, -0.017094761, -0.030970216, 0.005892701, 0.021898761, 0.015135726, -0.012546556, 0.013937845, 0.027351616, 0.034913242, -0.018292641, -0.0024706295, 0.00999482, -0.013176691, 0.01209735, 0.02534267, -0.00920871, -0.0025205412, -0.009034019, 0.0058552674, 0.004822719, 0.0067755147, -0.008191759, -0.006073631, 0.01330147, -0.0090714535, -0.006008122, 0.0066133016, 0.0213123, -0.0072621536, -0.0059738075, -0.005549558, 0.0012774278, -0.010575043, -0.031469334, -0.006688169, -4.0650746e-05, 0.014761388, -0.001173705, -0.024069922, -0.017044848, 0.008678398, 0.023633195, -0.0063231895, -0.0028153323, 0.01643343, 0.005917657, 0.0022974983, 0.021936197, 0.025292758, -0.006351265, -0.006048675, -0.031369507, 0.016957503, -0.032642256, 0.015672276, 0.0071560913, -0.009065215, -0.012814831, 0.004641789, -0.022422835, 0.0044982927, -0.028923836, 0.0036934665, 0.014649087, -0.011448498, 0.021923719, -0.02269735, -0.0027825779, -0.0008500588, -0.004719776, -0.04811489, -0.021511946, -0.009252383, 0.014237315, -0.016707944, -0.015784578, -0.018991405, 0.01674538, 0.02071336, 0.004429664, -0.0033877573, 0.003111683, 0.009352206, -0.021873806, -0.014299705, 0.010718539, 0.029971981, 0.031868625, 0.023882752, 0.009252383, 0.007829899, -0.029522777, 0.017256973, 0.010749734, 0.002991583, -0.019789992, -0.031269684, 0.00030180987, 0.015934313, -0.009427074, -0.009788934, -0.012927133, 0.002907357, 0.005633784, -0.0021118892, 0.010518893, -0.010606238, 0.0012243966, -0.006700647, -0.005321836, 0.004435903, -0.009882518, -0.0047416124, -0.009951147, 0.0076489695, -0.021224955, -0.03703449, 0.022734784, 0.020888051, 0.02745144, -0.008778222, 0.015485108, 0.032791995, 0.0041894643, 0.027526308, 0.0028387285, -0.012802353, 0.012902177, 0.019552913, -0.023882752, 0.0018108592, -0.021399645, 0.019827425, 0.0041333134, -0.005087875, -0.007873572, -0.024668863, -0.011691818, 0.020962918, 0.02630347, 0.02455656, 0.014985991, 0.024232134, 0.019240964, -0.011691818, -0.0058895815, -0.007848617, 0.02203602, 0.018866627, 0.0038182458, -0.027127014, -0.68918085, -0.011941376, -0.0006355944, 0.021050263, 0.034913242, 0.025255324, 0.005062919, 0.024044966, -0.011723013, 0.02184885, -0.027102059, 0.008547381, -0.017194584, -0.0038213653, 0.014012712, -0.013002, 0.013501117, -0.017893348, -0.013813065, 0.02221071, -0.025879221, 0.014698998, 0.0043142433, -0.0203515, 0.0023489697, -0.00553708, 0.0048320773, -0.018379986, -0.021274867, 0.04107734, -0.02745144, -0.003425191, -0.005140906, 0.010044731, 0.046692405, -0.029647555, -0.010849558, 0.028424717, -0.0072496757, 0.022198232, 0.0011518686, 0.0022288698, 0.011641906, -0.004744732, -0.00025384783, 0.015010946, 0.00920871, -0.010194466, -0.0072559146, -0.013675808, 0.017830959, -0.014923601, -0.021175042, 0.0046854615, -0.020002117, -0.00132422, -0.0060517946, 0.0097577395, 0.015984224, -0.00042113004, -0.021262389, -0.0019309593, -0.009595526, -0.0028917596, 0.0028792818, 0.005664979, -0.012059917, 0.009096409, 0.037333958, -0.023271333, -0.0056680986, 0.011192701, -0.019702647, -0.0009787374, 0.026178692, 0.017556444, 0.023608238, -0.028449673, -0.027201882, 0.017419185, -0.005303119, -0.017593877, -0.021711593, -0.007206003, 0.031743847, -0.0038868743, -0.03853184, 0.016408475, 0.003322248, -0.00758658, 0.02552984, 0.03853184, -0.0013959681, -0.0018404942, -0.011067921, -0.00051510445, 0.004 ...

# %%
from openai import OpenAI

client = OpenAI()

client.images.generate(
    model="dall-e-3", prompt="A cute baby sea otter", n=1, size="1024x1024"
)
# Out:
# ImagesResponse(created=1716513161, data=[Image(b64_json=None, revised_prompt='Visualize a scene of a baby sea otter looking incredibly cute. The otter is lying back comfortably on its back, afloat in a serene sea. With its soft, brown fur, tiny, rounded ears, and bright, sparkling eyes, the baby radiates innocence and curiosity. It is floating under a clear, blue sky, the sun casting a gentle glow on it. Surrounding the otter, the sea is teeming with colorful fishes, creating a stunning contrast and adding to the overall cuteness of the scene.', url='https://oaidalleapiprodscus.blob.core.windows.net/private/org-mqob61yrAJEcEHfN5DfMZSb5/user-ZaM44siMVAuvaiqDpImthFVL/img-fLltpCgmB6GNsnwp7j7tLAFK.png?st=2024-05-24T00%3A12%3A41Z&se=2024-05-24T02%3A12%3A41Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-05-23T22%3A46%3A26Z&ske=2024-05-24T22%3A46%3A26Z&sks=b&skv=2021-08-06&sig=g%2BrxXAl96N21juK2cwVsOZoohhPiEzbGpGdS2AGrM3c%3D')])
